# %%
import pandas as pd
import numpy as np

# %%
f1=pd.read_csv("/content/bert.csv")
f2=pd.read_csv("/content/bow_cat.csv")
f3=pd.read_csv("/content/bow_xgb.csv")
f4=pd.read_csv("/content/bert 74.csv")

# %%
f1.head()
# Out:
#       id  Analysis of PDEs  ...  Superconductivity  Systems and Control
# 0   9409               0.0  ...                0.0                  0.0
# 1  17934               0.0  ...                0.0                  0.0
# 2  16071               0.0  ...                0.0                  0.0
# 3  16870               1.0  ...                0.0                  0.0
# 4  10496               0.0  ...                0.0                  0.0
#
# [5 rows x 26 columns]

# %%
f4.head()
# Out:
#       id  Analysis of PDEs  ...  Superconductivity  Systems and Control
# 0   9409               0.0  ...                0.0                  0.0
# 1  17934               0.0  ...                0.0                  0.0
# 2  16071               0.0  ...                0.0                  0.0
# 3  16870               1.0  ...                0.0                  0.0
# 4  10496               0.0  ...                0.0                  0.0
#
# [5 rows x 26 columns]

# %%
res=f1.copy()
for i in range(f1.shape[0]):
  for j in range(1,f1.shape[1]):
    a=f4.iloc[i,j]+f2.iloc[i,j]+f3.iloc[i,j]
    if(a>1):
      res.iloc[i,j]=1
    else:
      res.iloc[i,j]=0

# %%
res.head()
# Out:
#       id  Analysis of PDEs  ...  Superconductivity  Systems and Control
# 0   9409               0.0  ...                0.0                  0.0
# 1  17934               0.0  ...                0.0                  0.0
# 2  16071               0.0  ...                0.0                  0.0
# 3  16870               1.0  ...                0.0                  0.0
# 4  10496               0.0  ...                0.0                  0.0
#
# [5 rows x 26 columns]

# %%
res.to_csv('ens_bow_cat_xgb_bert.csv',index=False)
